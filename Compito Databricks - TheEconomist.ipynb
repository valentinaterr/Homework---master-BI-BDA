# %%
# %sql

select * from default.dataset
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>Title</th><th>Section</th></tr></thead><tbody><tr><td>0</td><td>The WTO’s outgoing boss leaves behind a hobbled body</td><td>finance and economics</td></tr><tr><td>1</td><td>For fixed-income investors, hell is other bondholders</td><td>finance and economics</td></tr><tr><td>2</td><td>Psychological scars of downturns could depress growth for decades</td><td>finance and economics</td></tr><tr><td>3</td><td>Nicolai Tangen pays a big price for his new gig</td><td>finance and economics</td></tr><tr><td>4</td><td>The explosion at Beirut’s port will blow a hole in insurers’ balance-sheets</td><td>finance and economics</td></tr><tr><td>5</td><td>Efforts to rein in house prices are fuelling discontent in Seoul</td><td>finance and economics</td></tr><tr><td>6</td><td>In twenty years, exchanges have gone from clubby firms to huge conglomerates</td><td>finance and economics</td></tr><tr><td>7</td><td>Ant Group IPO filing shows its might</td><td>finance and economics</td></tr><tr><td>8</td><td>Phil Hogan, Europe’s trade commissioner, resigns</td><td>finance and economics</td></tr><tr><td>9</td><td>The Fed makes its biggest inflation-policy change in decades</td><td>finance and economics</td></tr><tr><td>10</td><td>China’s monetary stimulus is unusually restrained</td><td>finance and economics</td></tr><tr><td>11</td><td>Can Dubai enter the premier league of financial centres?</td><td>finance and economics</td></tr><tr><td>12</td><td>Why the economic value of a face mask is $56.14</td><td>finance and economics</td></tr><tr><td>13</td><td>America’s fiscal federalism is less superior than you might think</td><td>finance and economics</td></tr><tr><td>14</td><td>Bubble-hunting has become more art than science</td><td>finance and economics</td></tr><tr><td>15</td><td>A new study shows emerging economies are catching up</td><td>finance and economics</td></tr><tr><td>16</td><td>Blended finance is struggling to take off</td><td>finance and economics</td></tr><tr><td>17</td><td>As the lira slides, what will Turkey’s central bank do?</td><td>finance and economics</td></tr><tr><td>18</td><td>Should personal financial data be sent to foreign tax authorities?</td><td>finance and economics</td></tr><tr><td>19</td><td>Has the ECB found a way around the lower bound on interest rates?</td><td>finance and economics</td></tr><tr><td>20</td><td>In India, gold-based finance is booming</td><td>finance and economics</td></tr><tr><td>21</td><td>What it takes to become an academic economist is changing</td><td>finance and economics</td></tr><tr><td>22</td><td>Dollar dominance is as secure as American global leadership</td><td>finance and economics</td></tr><tr><td>23</td><td>Hard questions as scientists and governments seek covid-19 vaccines</td><td>finance and economics</td></tr><tr><td>24</td><td>Why European banks expect fewer bad loans than American rivals</td><td>finance and economics</td></tr><tr><td>25</td><td>Do Alipay and Tenpay misuse their market power?</td><td>finance and economics</td></tr><tr><td>26</td><td>Official economic forecasts for poor countries are too rosy</td><td>finance and economics</td></tr><tr><td>27</td><td>Has India’s moratorium on loan payments delayed the pain for banks?</td><td>finance and economics</td></tr><tr><td>28</td><td>The EU’s recovery fund revives a debate on common taxes</td><td>finance and economics</td></tr><tr><td>29</td><td>In emerging markets, short-term panic gives way to long-term worry</td><td>finance and economics</td></tr><tr><td>30</td><td>Bridgewater faces losses and a lawsuit</td><td>finance and economics</td></tr><tr><td>31</td><td>The SPAC hack</td><td>finance and economics</td></tr><tr><td>32</td><td>The price of gold surges to an all-time high</td><td>finance and economics</td></tr><tr><td>33</td><td>The fear of robots displacing workers has returned</td><td>finance and econ ...

# %%
# %sql

select count(Title) from default.dataset
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(Title)</th></tr></thead><tbody><tr><td>13951</td></tr></tbody></table></div>

# %%
# %sql

select count(distinct Title) from default.dataset
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(DISTINCT Title)</th></tr></thead><tbody><tr><td>7200</td></tr></tbody></table></div>

# %%
# %sql 

select Section, count(distinct Title) num from default.dataset group by Section order by num desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Section</th><th>num</th></tr></thead><tbody><tr><td>finance and economics</td><td>4562</td></tr><tr><td>science-and-technology</td><td>1539</td></tr><tr><td>books-and-arts</td><td>1158</td></tr></tbody></table></div>

# %%
ds_dataset = spark.sql("select * from dataset where _c0 < 1250 or _c0 > 4500").dropDuplicates(['Title'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ds_dataset.createOrReplaceTempView("ds_dataset")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql

select Section, count(Title) num from ds_dataset group by Section order by num desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Section</th><th>num</th></tr></thead><tbody><tr><td>science-and-technology</td><td>1524</td></tr><tr><td>finance and economics</td><td>1498</td></tr><tr><td>books-and-arts</td><td>1148</td></tr></tbody></table></div>

# %%
train, test = ds_dataset.randomSplit([0.8, 0.2], seed=12345)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
train.createOrReplaceTempView("train")
train_dataset = spark.sql("select * from train")

display(train_dataset.select("*").limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>Title</th><th>Section</th></tr></thead><tbody><tr><td>230</td><td>Kreppanomics</td><td>finance and economics</td></tr><tr><td>877</td><td>Difference of opinion</td><td>finance and economics</td></tr><tr><td>1217</td><td>Long ranger</td><td>finance and economics</td></tr><tr><td>4691</td><td>Bohemia’s fading rhapsody</td><td>finance and economics</td></tr><tr><td>4859</td><td>Covid-19 has many faces</td><td>science-and-technology</td></tr><tr><td>4944</td><td>Trials and transparency</td><td>science-and-technology</td></tr><tr><td>5430</td><td>How to save 1m children a year</td><td>science-and-technology</td></tr><tr><td>5992</td><td>Beneath the Southern Cross I stand</td><td>science-and-technology</td></tr><tr><td>6088</td><td>Bursting into life</td><td>science-and-technology</td></tr><tr><td>6320</td><td>Silicon waves</td><td>science-and-technology</td></tr></tbody></table></div>

# %%
from pyspark.ml.feature import RegexTokenizer
from pyspark.sql.functions import col, udf
from pyspark.sql.types import IntegerType

regexTokenizer = RegexTokenizer(inputCol= "Title", outputCol = "words", pattern = "\\W")
tokenized = regexTokenizer.transform(train_dataset)

countTokens = udf(lambda words: len(words), IntegerType())
tokenized_counts = tokenized.select("Title", "words","Section").withColumn("tokens", countTokens(col("words")))

##remove rows with only one token
tokenized_counts.createOrReplaceTempView("tokenized_counts")
tokenized = spark.sql("select * from tokenized_counts where tokens > 1")
##

display(tokenized_counts.select("*").limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Title</th><th>words</th><th>Section</th><th>tokens</th></tr></thead><tbody><tr><td>Kreppanomics</td><td>List(kreppanomics)</td><td>finance and economics</td><td>1</td></tr><tr><td>Difference of opinion</td><td>List(difference, of, opinion)</td><td>finance and economics</td><td>3</td></tr><tr><td>Long ranger</td><td>List(long, ranger)</td><td>finance and economics</td><td>2</td></tr><tr><td>Bohemia’s fading rhapsody</td><td>List(bohemia, s, fading, rhapsody)</td><td>finance and economics</td><td>4</td></tr><tr><td>Covid-19 has many faces</td><td>List(covid, 19, has, many, faces)</td><td>science-and-technology</td><td>5</td></tr><tr><td>Trials and transparency</td><td>List(trials, and, transparency)</td><td>science-and-technology</td><td>3</td></tr><tr><td>How to save 1m children a year</td><td>List(how, to, save, 1m, children, a, year)</td><td>science-and-technology</td><td>7</td></tr><tr><td>Beneath the Southern Cross I stand</td><td>List(beneath, the, southern, cross, i, stand)</td><td>science-and-technology</td><td>6</td></tr><tr><td>Bursting into life</td><td>List(bursting, into, life)</td><td>science-and-technology</td><td>3</td></tr><tr><td>Silicon waves</td><td>List(silicon, waves)</td><td>science-and-technology</td><td>2</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import explode, desc

tokens = tokenized.select(explode(col("words")).alias("word")).groupby(col("word")).count().orderBy(desc("count"))
display(tokens.select("*").limit(20))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>word</th><th>count</th></tr></thead><tbody><tr><td>the</td><td>947</td></tr><tr><td>a</td><td>411</td></tr><tr><td>of</td><td>393</td></tr><tr><td>and</td><td>214</td></tr><tr><td>in</td><td>210</td></tr><tr><td>s</td><td>192</td></tr><tr><td>to</td><td>172</td></tr><tr><td>for</td><td>117</td></tr><tr><td>on</td><td>112</td></tr><tr><td>it</td><td>81</td></tr><tr><td>is</td><td>72</td></tr><tr><td>up</td><td>68</td></tr><tr><td>not</td><td>65</td></tr><tr><td>new</td><td>61</td></tr><tr><td>an</td><td>60</td></tr><tr><td>out</td><td>55</td></tr><tr><td>at</td><td>52</td></tr><tr><td>with</td><td>45</td></tr><tr><td>all</td><td>44</td></tr><tr><td>or</td><td>43</td></tr></tbody></table></div>

# %%
from pyspark.ml.feature import StopWordsRemover
remover = StopWordsRemover(inputCol = "words", outputCol = "cleaned", caseSensitive = False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
remover.setStopWords(StopWordsRemover.loadDefaultStopWords("english"))
cleaned = remover.transform(tokenized)

cleaned.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------------------+--------------------+------+--------------------+
#                Title|               words|             Section|tokens|             cleaned|
# +--------------------+--------------------+--------------------+------+--------------------+
# Difference of opi...|[difference, of, ...|finance and econo...|     3|[difference, opin...|
#          Long ranger|      [long, ranger]|finance and econo...|     2|      [long, ranger]|
# Bohemia’s fading ...|[bohemia, s, fadi...|finance and econo...|     4|[bohemia, fading,...|
# Covid-19 has many...|[covid, 19, has, ...|science-and-techn...|     5|[covid, 19, many,...|
# Trials and transp...|[trials, and, tra...|science-and-techn...|     3|[trials, transpar...|
# How to save 1m ch...|[how, to, save, 1...|science-and-techn...|     7|[save, 1m, childr...|
# Beneath the South...|[beneath, the, so...|science-and-techn...|     6|[beneath, souther...|
#   Bursting into life|[bursting, into, ...|science-and-techn...|     3|    [bursting, life]|
#        Silicon waves|    [silicon, waves]|science-and-techn...|     2|    [silicon, waves]|
# Two authors wrest...|[two, authors, wr...|      books-and-arts|    10|[two, authors, wr...|
# Voices from the past|[voices, from, th...|      books-and-arts|     4|      [voices, past]|
#         Up the creek|    [up, the, creek]|      books-and-arts|     3|             [creek]|
#      Renaissance man|  [renaissance, man]|      books-and-arts|     2|  [renaissance, man]|
# Treachery, egotis...|[treachery, egoti...|      books-and-arts|     4|[treachery, egoti...|
#      East makes West| [east, makes, west]|      books-and-arts|     3| [east, makes, west]|
#       Paint it black|  [paint, it, black]|finance and econo...|     3|      [paint, black]|
#        Alpha betting|    [alpha, betting]|finance and econo...|     2|    [alpha, betting]|
# Debt and destruction|[debt, and, destr...|finance and econo...|     3| [debt, destruction]|
#     A numbers racket|[a, numbers, racket]|finance and econo...|     3|   [numbers, racket]|
#       Les misérables|  [les, mis, rables]|finance and econo...|     3|  [les, mis, rables]|
# +--------------------+--------------------+--------------------+------+--------------------+
# only showing top 20 rows
#
# </div>

# %%
tokens = cleaned.select(explode(col("cleaned")).alias("word")).groupBy(col("word")).count().orderBy(desc("count"))
display(tokens.select("*").limit(20))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>word</th><th>count</th></tr></thead><tbody><tr><td>new</td><td>61</td></tr><tr><td>big</td><td>34</td></tr><tr><td>world</td><td>29</td></tr><tr><td>man</td><td>27</td></tr><tr><td>life</td><td>27</td></tr><tr><td>time</td><td>25</td></tr><tr><td>light</td><td>25</td></tr><tr><td>first</td><td>21</td></tr><tr><td>money</td><td>20</td></tr><tr><td>one</td><td>20</td></tr><tr><td>end</td><td>19</td></tr><tr><td>going</td><td>19</td></tr><tr><td>good</td><td>19</td></tr><tr><td>war</td><td>18</td></tr><tr><td>last</td><td>18</td></tr><tr><td>getting</td><td>17</td></tr><tr><td>two</td><td>17</td></tr><tr><td>home</td><td>16</td></tr><tr><td>another</td><td>16</td></tr><tr><td>covid</td><td>16</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import udf
from pyspark.sql.types import ArrayType, StringType

# define our custom function to remove too short terms
def filter_by_len(words):
  filtered = [word for word in words if len(word) > 2]
  return filtered

# register our function as udf
filter_by_len_udf = udf(filter_by_len, ArrayType(StringType()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
filtered = cleaned.withColumn("filtered", filter_by_len_udf(col("cleaned")))
display(filtered.select("*").limit(20))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Title</th><th>words</th><th>Section</th><th>tokens</th><th>cleaned</th><th>filtered</th></tr></thead><tbody><tr><td>Difference of opinion</td><td>List(difference, of, opinion)</td><td>finance and economics</td><td>3</td><td>List(difference, opinion)</td><td>List(difference, opinion)</td></tr><tr><td>Long ranger</td><td>List(long, ranger)</td><td>finance and economics</td><td>2</td><td>List(long, ranger)</td><td>List(long, ranger)</td></tr><tr><td>Bohemia’s fading rhapsody</td><td>List(bohemia, s, fading, rhapsody)</td><td>finance and economics</td><td>4</td><td>List(bohemia, fading, rhapsody)</td><td>List(bohemia, fading, rhapsody)</td></tr><tr><td>Covid-19 has many faces</td><td>List(covid, 19, has, many, faces)</td><td>science-and-technology</td><td>5</td><td>List(covid, 19, many, faces)</td><td>List(covid, many, faces)</td></tr><tr><td>Trials and transparency</td><td>List(trials, and, transparency)</td><td>science-and-technology</td><td>3</td><td>List(trials, transparency)</td><td>List(trials, transparency)</td></tr><tr><td>How to save 1m children a year</td><td>List(how, to, save, 1m, children, a, year)</td><td>science-and-technology</td><td>7</td><td>List(save, 1m, children, year)</td><td>List(save, children, year)</td></tr><tr><td>Beneath the Southern Cross I stand</td><td>List(beneath, the, southern, cross, i, stand)</td><td>science-and-technology</td><td>6</td><td>List(beneath, southern, cross, stand)</td><td>List(beneath, southern, cross, stand)</td></tr><tr><td>Bursting into life</td><td>List(bursting, into, life)</td><td>science-and-technology</td><td>3</td><td>List(bursting, life)</td><td>List(bursting, life)</td></tr><tr><td>Silicon waves</td><td>List(silicon, waves)</td><td>science-and-technology</td><td>2</td><td>List(silicon, waves)</td><td>List(silicon, waves)</td></tr><tr><td>Two authors wrestle with inequality and the allure of populism</td><td>List(two, authors, wrestle, with, inequality, and, the, allure, of, populism)</td><td>books-and-arts</td><td>10</td><td>List(two, authors, wrestle, inequality, allure, populism)</td><td>List(two, authors, wrestle, inequality, allure, populism)</td></tr><tr><td>Voices from the past</td><td>List(voices, from, the, past)</td><td>books-and-arts</td><td>4</td><td>List(voices, past)</td><td>List(voices, past)</td></tr><tr><td>Up the creek</td><td>List(up, the, creek)</td><td>books-and-arts</td><td>3</td><td>List(creek)</td><td>List(creek)</td></tr><tr><td>Renaissance man</td><td>List(renaissance, man)</td><td>books-and-arts</td><td>2</td><td>List(renaissance, man)</td><td>List(renaissance, man)</td></tr><tr><td>Treachery, egotism or bravery?</td><td>List(treachery, egotism, or, bravery)</td><td>books-and-arts</td><td>4</td><td>List(treachery, egotism, bravery)</td><td>List(treachery, egotism, bravery)</td></tr><tr><td>East makes West</td><td>List(east, makes, west)</td><td>books-and-arts</td><td>3</td><td>List(east, makes, west)</td><td>List(east, makes, west)</td></tr><tr><td>Paint it black</td><td>List(paint, it, black)</td><td>finance and economics</td><td>3</td><td>List(paint, black)</td><td>List(paint, black)</td></tr><tr><td>Alpha betting</td><td>List(alpha, betting)</td><td>finance and economics</td><td>2</td><td>List(alpha, betting)</td><td>List(alpha, betting)</td></tr><tr><td>Debt and destruction</td><td>List(debt, and, destruction)</td><td>finance and economics</td><td>3</td><td>List(debt, destruction)</td><td>List(debt, destruction)</td></tr><tr><td>A numbers racket</td><td>List(a, numbers, racket)</td><td>finance and economics</td><td>3</td><td>List(numbers, racket)</td><td>List(numbers, racket)</td></tr><tr><td>Les misérables</td><td>List(les, mis, rables)</td><td>finance and economics</td><td>3</td><td>List(les, mis, rables)</td><td>List(les, mis, rables)</td></tr></tbody></table></div>

# %%
from pyspark.ml.feature import NGram
ngrams2 = NGram(n=2, inputCol = "cleaned", outputCol = "ngrams_2")
ngrams = ngrams2.transform(filtered)

ngrams.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------------------+--------------------+------+--------------------+--------------------+--------------------+
#                Title|               words|             Section|tokens|             cleaned|            filtered|            ngrams_2|
# +--------------------+--------------------+--------------------+------+--------------------+--------------------+--------------------+
# Difference of opi...|[difference, of, ...|finance and econo...|     3|[difference, opin...|[difference, opin...|[difference opinion]|
#          Long ranger|      [long, ranger]|finance and econo...|     2|      [long, ranger]|      [long, ranger]|       [long ranger]|
# Bohemia’s fading ...|[bohemia, s, fadi...|finance and econo...|     4|[bohemia, fading,...|[bohemia, fading,...|[bohemia fading, ...|
# Covid-19 has many...|[covid, 19, has, ...|science-and-techn...|     5|[covid, 19, many,...|[covid, many, faces]|[covid 19, 19 man...|
# Trials and transp...|[trials, and, tra...|science-and-techn...|     3|[trials, transpar...|[trials, transpar...|[trials transpare...|
# How to save 1m ch...|[how, to, save, 1...|science-and-techn...|     7|[save, 1m, childr...|[save, children, ...|[save 1m, 1m chil...|
# Beneath the South...|[beneath, the, so...|science-and-techn...|     6|[beneath, souther...|[beneath, souther...|[beneath southern...|
#   Bursting into life|[bursting, into, ...|science-and-techn...|     3|    [bursting, life]|    [bursting, life]|     [bursting life]|
#        Silicon waves|    [silicon, waves]|science-and-techn...|     2|    [silicon, waves]|    [silicon, waves]|     [silicon waves]|
# Two authors wrest...|[two, authors, wr...|      books-and-arts|    10|[two, authors, wr...|[two, authors, wr...|[two authors, aut...|
# Voices from the past|[voices, from, th...|      books-and-arts|     4|      [voices, past]|      [voices, past]|       [voices past]|
#         Up the creek|    [up, the, creek]|      books-and-arts|     3|             [creek]|             [creek]|                  []|
#      Renaissance man|  [renaissance, man]|      books-and-arts|     2|  [renaissance, man]|  [renaissance, man]|   [renaissance man]|
# Treachery, egotis...|[treachery, egoti...|      books-and-arts|     4|[treachery, egoti...|[treachery, egoti...|[treachery egotis...|
#      East makes West| [east, makes, west]|      books-and-arts|     3| [east, makes, west]| [east, makes, west]|[east makes, make...|
#       Paint it black|  [paint, it, black]|finance and econo...|     3|      [paint, black]|      [paint, black]|       [paint black]|
#        Alpha betting|    [alpha, betting]|finance and econo...|     2|    [alpha, betting]|    [alpha, betting]|     [alpha betting]|
# Debt and destruction|[debt, and, destr...|finance and econo...|     3| [debt, destruction]| [debt, destruction]|  [debt destruction]|
#     A numbers racket|[a, numbers, racket]|finance and econo...|     3|   [numbers, racket]|   [numbers, racket]|    [numbers racket]|
#       Les misérables|  [les, mis, rables]|finance and econo...|     3|  [les, mis, rables]|  [les, mis, rables]|[les mis, mis rab...|
# +--------------------+--------------------+--------------------+------+--------------------+--------------------+--------------------+
# only showing top 20 rows
#
# </div>

# %%
def union_ngrams(c1,c2):
  return c1 + c2

union_ngrams_udf = udf(union_ngrams, ArrayType(StringType()))

ngrams_final = ngrams.filter("filtered is not Null").withColumn("ngrams", union_ngrams_udf(col("filtered"), col("ngrams_2")))
ngrams_final.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------------------+--------------------+------+--------------------+--------------------+--------------------+--------------------+
#                Title|               words|             Section|tokens|             cleaned|            filtered|            ngrams_2|              ngrams|
# +--------------------+--------------------+--------------------+------+--------------------+--------------------+--------------------+--------------------+
# Difference of opi...|[difference, of, ...|finance and econo...|     3|[difference, opin...|[difference, opin...|[difference opinion]|[difference, opin...|
#          Long ranger|      [long, ranger]|finance and econo...|     2|      [long, ranger]|      [long, ranger]|       [long ranger]|[long, ranger, lo...|
# Bohemia’s fading ...|[bohemia, s, fadi...|finance and econo...|     4|[bohemia, fading,...|[bohemia, fading,...|[bohemia fading, ...|[bohemia, fading,...|
# Covid-19 has many...|[covid, 19, has, ...|science-and-techn...|     5|[covid, 19, many,...|[covid, many, faces]|[covid 19, 19 man...|[covid, many, fac...|
# Trials and transp...|[trials, and, tra...|science-and-techn...|     3|[trials, transpar...|[trials, transpar...|[trials transpare...|[trials, transpar...|
# How to save 1m ch...|[how, to, save, 1...|science-and-techn...|     7|[save, 1m, childr...|[save, children, ...|[save 1m, 1m chil...|[save, children, ...|
# Beneath the South...|[beneath, the, so...|science-and-techn...|     6|[beneath, souther...|[beneath, souther...|[beneath southern...|[beneath, souther...|
#   Bursting into life|[bursting, into, ...|science-and-techn...|     3|    [bursting, life]|    [bursting, life]|     [bursting life]|[bursting, life, ...|
#        Silicon waves|    [silicon, waves]|science-and-techn...|     2|    [silicon, waves]|    [silicon, waves]|     [silicon waves]|[silicon, waves, ...|
# Two authors wrest...|[two, authors, wr...|      books-and-arts|    10|[two, authors, wr...|[two, authors, wr...|[two authors, aut...|[two, authors, wr...|
# Voices from the past|[voices, from, th...|      books-and-arts|     4|      [voices, past]|      [voices, past]|       [voices past]|[voices, past, vo...|
#         Up the creek|    [up, the, creek]|      books-and-arts|     3|             [creek]|             [creek]|                  []|             [creek]|
#      Renaissance man|  [renaissance, man]|      books-and-arts|     2|  [renaissance, man]|  [renaissance, man]|   [renaissance man]|[renaissance, man...|
# Treachery, egotis...|[treachery, egoti...|      books-and-arts|     4|[treachery, egoti...|[treachery, egoti...|[treachery egotis...|[treachery, egoti...|
#      East makes West| [east, makes, west]|      books-and-arts|     3| [east, makes, west]| [east, makes, west]|[east makes, make...|[east, makes, wes...|
#       Paint it black|  [paint, it, black]|finance and econo...|     3|      [paint, black]|      [paint, black]|       [paint black]|[paint, black, pa...|
#        Alpha betting|    [alpha, betting]|finance and econo...|     2|    [alpha, betting]|    [alpha, betting]|     [alpha betting]|[alpha, betting, ...|
# Debt and destruction|[debt, and, destr...|finance and econo...|     3| [debt, destruction]| [debt, destruction]|  [debt destruction]|[debt, destructio...|
#     A numbers racket|[a, numbers, racket]|finance and econo...|     3|   [numbers, racket]|   [numbers, racket]|    [numbers racket]|[numbers, racket,...|
#       Les misérables|  [les, mis, rables]|finance and econo...|     3|  [les, mis, rables]|  [les, mis, rables]|[les mis, mis rab...|[les, mis, rables...|
# +--------------------+--------------------+--------------------+------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows
#
# </div>

# %%
from pyspark.ml.feature import HashingTF
from pyspark.ml.feature import IDF

hashing_tf = HashingTF(inputCol="ngrams", outputCol="rawFeatures")
idf = IDF(inputCol="rawFeatures", outputCol="features")
hash_dataset = hashing_tf.transform(ngrams_final)

idf_model = idf.fit(hash_dataset)
idf_dataset = idf_model.transform(hash_dataset)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.ml.feature import IndexToString, StringIndexer

indexer = StringIndexer(inputCol = "Section", outputCol = "label")
indexer_model = indexer.fit(idf_dataset)
indexed = indexer_model.transform(idf_dataset)
converter = IndexToString(inputCol = "prediction", outputCol ="prediction_category", labels=indexer_model.labels)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.ml.classification import NaiveBayes
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.tuning import ParamGridBuilder, TrainValidationSplit

nb = NaiveBayes(smoothing=1.0, modelType="multinomial", labelCol ="label", featuresCol = "features")
paramGrid = ParamGridBuilder()\
    .addGrid(nb.smoothing, [0.1,0.5,1.0]) \
    .build()

tvs = TrainValidationSplit(estimator=nb,
                          estimatorParamMaps=paramGrid,
                          evaluator=MulticlassClassificationEvaluator(),
                          trainRatio=0.8)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
nb_model = tvs.fit(indexed)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
test.createOrReplaceTempView("test")
test_dataset = spark.sql("select * from test")
test_tokenized = regexTokenizer.transform(test_dataset)
test_cleaned = remover.transform(test_tokenized)
test_filtered = test_cleaned.withColumn("filtered", filter_by_len_udf(col("cleaned")))
test_ngrams = ngrams2.transform(test_filtered)
test_ngrams_final = test_ngrams.filter("filtered is not Null").withColumn("ngrams", union_ngrams_udf(col("filtered"), col("ngrams_2")))

test_hash_dataset = hashing_tf.transform(test_ngrams_final)
test_idf_dataset = idf_model.transform(test_hash_dataset)
test_indexed = indexer_model.transform(test_idf_dataset)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
predictions = nb_model.transform(test_indexed).select("Title", "label", "prediction", "Section")
predictions_decoded = converter.transform(predictions)
display(predictions_decoded.select("*").limit(20))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Title</th><th>label</th><th>prediction</th><th>Section</th><th>prediction_category</th></tr></thead><tbody><tr><td>Trials of a vaccine and new drug raise hope of beating covid-19</td><td>0.0</td><td>0.0</td><td>science-and-technology</td><td>science-and-technology</td></tr><tr><td>A mystery no longer</td><td>0.0</td><td>1.0</td><td>science-and-technology</td><td>finance and economics</td></tr><tr><td>The life in an ocean wave</td><td>0.0</td><td>0.0</td><td>science-and-technology</td><td>science-and-technology</td></tr><tr><td>Think again</td><td>2.0</td><td>1.0</td><td>books-and-arts</td><td>finance and economics</td></tr><tr><td>The myth of structure</td><td>2.0</td><td>0.0</td><td>books-and-arts</td><td>science-and-technology</td></tr><tr><td>Independent eye</td><td>2.0</td><td>0.0</td><td>books-and-arts</td><td>science-and-technology</td></tr><tr><td>Unscrambling the eggs</td><td>1.0</td><td>2.0</td><td>finance and economics</td><td>books-and-arts</td></tr><tr><td>One qubit at a time</td><td>0.0</td><td>2.0</td><td>science-and-technology</td><td>books-and-arts</td></tr><tr><td>The collider calamity</td><td>0.0</td><td>2.0</td><td>science-and-technology</td><td>books-and-arts</td></tr><tr><td>The end of Mir</td><td>0.0</td><td>0.0</td><td>science-and-technology</td><td>science-and-technology</td></tr><tr><td>The virtues of dog training in lockdown</td><td>2.0</td><td>2.0</td><td>books-and-arts</td><td>books-and-arts</td></tr><tr><td>Print the legend</td><td>2.0</td><td>2.0</td><td>books-and-arts</td><td>books-and-arts</td></tr><tr><td>Inky devils</td><td>2.0</td><td>2.0</td><td>books-and-arts</td><td>books-and-arts</td></tr><tr><td>Making sense of Bernanke</td><td>1.0</td><td>0.0</td><td>finance and economics</td><td>science-and-technology</td></tr><tr><td>They can’t all be masters</td><td>1.0</td><td>2.0</td><td>finance and economics</td><td>books-and-arts</td></tr><tr><td>Testing the waters</td><td>1.0</td><td>0.0</td><td>finance and economics</td><td>science-and-technology</td></tr><tr><td>Bye-bye EMBI</td><td>1.0</td><td>2.0</td><td>finance and economics</td><td>books-and-arts</td></tr><tr><td>Privatisation, sort of</td><td>1.0</td><td>1.0</td><td>finance and economics</td><td>finance and economics</td></tr><tr><td>The whine of success</td><td>1.0</td><td>0.0</td><td>finance and economics</td><td>science-and-technology</td></tr><tr><td>Buddy system</td><td>1.0</td><td>1.0</td><td>finance and economics</td><td>finance and economics</td></tr></tbody></table></div>

# %%
evaluator_precision = MulticlassClassificationEvaluator(labelCol="label", predictionCol = "prediction", metricName = "weightedPrecision")

precision = evaluator_precision.evaluate(predictions)
print("Test set weighted precision = " + str(precision))

evaluator_recall = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName = "weightedRecall")
recall = evaluator_recall.evaluate(predictions)
print("Test set weighted recall = " + str(recall))

evaluator_f1 = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName = "f1")

f1 = evaluator_f1.evaluate(predictions)
print("Test set f1 = " + str(f1))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Test set weighted precision = 0.4841227990851601
# Test set weighted recall = 0.4691075514874142
# Test set f1 = 0.4709741983478627
# </div>
